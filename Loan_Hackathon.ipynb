# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import matplotlib as mat 
import seaborn as sns
from tabulate import tabulate 
from scipy import stats

# %%
df = pd.read_csv("C:\\Users\\ROBOT\\Downloads\\data (2).csv")
df
# Out:
#        SK_ID_CURR  TARGET NAME_CONTRACT_TYPE GENDER Car House  CNT_CHILDREN  \
# 0          100002       1         Cash loans      M   N     Y             0
# 1          100003       0         Cash loans      F   N     N             0
# 2          100004       0    Revolving loans      M   Y     Y             0
# 3          100006       0         Cash loans      F   N     Y             0
# 4          100007       0         Cash loans      M   N     Y             0
# ...           ...     ...                ...    ...  ..   ...           ...
# 99995      216086       0         Cash loans      F   N     Y             1
# 99996      216087       0         Cash loans      F   N     Y             1
# 99997      216088       0         Cash loans      F   Y     Y             0
# 99998      216089       0         Cash loans      F   Y     N             0
# 99999      216090       0    Revolving loans      M   Y     Y             0
#
# ...

# %%
df.isnull().sum()
# Out:
# SK_ID_CURR                 0
# TARGET                     0
# NAME_CONTRACT_TYPE         0
# GENDER                     0
# Car                        0
# House                      0
# CNT_CHILDREN               0
# AMT_INCOME_TOTAL           0
# AMT_CREDIT                 0
# AMT_GOODS_PRICE           81
# NAME_TYPE_SUITE          405
# NAME_INCOME_TYPE           0
# NAME_EDUCATION_TYPE        0
# NAME_FAMILY_STATUS         0
# DAYS_EMPLOYED              0
# MOBILE                     0
# WORK_PHONE                 0
# HOME_PHONE                 0
# MOBILE_REACHABLE           0
# FLAG_EMAIL                 0
# OCCUPATION_TYPE        31224
# CNT_FAM_MEMBERS            1
# APPLICATION_DAY            0
# TOTAL_DOC_SUBMITTED        0
# dtype: int64

# %%
df['AMT_GOODS_PRICE'].mean()
# Out:
# 538345.1489706662

# %%
df['AMT_GOODS_PRICE'] = df['AMT_GOODS_PRICE'].fillna(538345)

# %%
df['NAME_TYPE_SUITE'].mode()
# Out:
# 0    Unaccompanied
# dtype: object

# %%
df['NAME_TYPE_SUITE'] = df['NAME_TYPE_SUITE'].fillna('Unaccompanied')

# %%
df.isnull().sum()
# Out:
# SK_ID_CURR                 0
# TARGET                     0
# NAME_CONTRACT_TYPE         0
# GENDER                     0
# Car                        0
# House                      0
# CNT_CHILDREN               0
# AMT_INCOME_TOTAL           0
# AMT_CREDIT                 0
# AMT_GOODS_PRICE            0
# NAME_TYPE_SUITE            0
# NAME_INCOME_TYPE           0
# NAME_EDUCATION_TYPE        0
# NAME_FAMILY_STATUS         0
# DAYS_EMPLOYED              0
# MOBILE                     0
# WORK_PHONE                 0
# HOME_PHONE                 0
# MOBILE_REACHABLE           0
# FLAG_EMAIL                 0
# OCCUPATION_TYPE        31224
# CNT_FAM_MEMBERS            1
# APPLICATION_DAY            0
# TOTAL_DOC_SUBMITTED        0
# dtype: int64

# %%
df=df.dropna()

# %%
df.isnull().sum()
# Out:
# SK_ID_CURR             0
# TARGET                 0
# NAME_CONTRACT_TYPE     0
# GENDER                 0
# Car                    0
# House                  0
# CNT_CHILDREN           0
# AMT_INCOME_TOTAL       0
# AMT_CREDIT             0
# AMT_GOODS_PRICE        0
# NAME_TYPE_SUITE        0
# NAME_INCOME_TYPE       0
# NAME_EDUCATION_TYPE    0
# NAME_FAMILY_STATUS     0
# DAYS_EMPLOYED          0
# MOBILE                 0
# WORK_PHONE             0
# HOME_PHONE             0
# MOBILE_REACHABLE       0
# FLAG_EMAIL             0
# OCCUPATION_TYPE        0
# CNT_FAM_MEMBERS        0
# APPLICATION_DAY        0
# TOTAL_DOC_SUBMITTED    0
# dtype: int64

# %%
df.describe()
# Out:
#           SK_ID_CURR        TARGET  CNT_CHILDREN  AMT_INCOME_TOTAL  \
# count   68775.000000  68775.000000  68775.000000      6.877500e+04
# mean   158075.595347      0.088346      0.501490      1.770188e+05
# std     33515.842885      0.283800      0.762652      4.580935e+05
# min    100002.000000      0.000000      0.000000      2.565000e+04
# 25%    129091.500000      0.000000      0.000000      1.125000e+05
# 50%    157959.000000      0.000000      0.000000      1.575000e+05
# 75%    187150.500000      0.000000      1.000000      2.115000e+05
# max    216090.000000      1.000000     12.000000      1.170000e+08
#
#          AMT_CREDIT  AMT_GOODS_PRICE  DAYS_EMPLOYED   MOBILE    WORK_PHONE  \
# count  6.877500e+04     6.877500e+04   68775.000000  68775.0  68775.000000
# mean   6.110767e+05     5.486472e+05   -2375.929495      1.0      0.999927
# std    4.060585e+05     3.728965e+05    2337.414997      0.0      0.008526
# ...

# %%
fig, ax = plt.subplots(1, figsize = (15, 7))
percentage = df["TARGET"].value_counts()     
labels = list(df["TARGET"].value_counts().index)
plt.pie(percentage,labels = ['Non Default','Defaulter'], autopct= "%0.2f%%")  
plt.show()

# %%
def seprate_data_types(df): 
    categorical = []
    continuous = []
    
    for column in df.columns:
      
        if df[column].nunique() <20 : 
            categorical.append(column)
        else:
            continuous.append(column)
 
    return categorical, continuous 

categorical, continuous = seprate_data_types(df) 

table = [categorical, continuous]


print(tabulate({"Categorical":categorical, "Continuous": continuous}, headers = ["categorical", "continuous"]))
# Out:
# categorical          continuous
# -------------------  ----------------
# TARGET               SK_ID_CURR
# NAME_CONTRACT_TYPE   AMT_INCOME_TOTAL
# GENDER               AMT_CREDIT
# Car                  AMT_GOODS_PRICE
# House                DAYS_EMPLOYED
# CNT_CHILDREN
# NAME_TYPE_SUITE
# NAME_INCOME_TYPE
# NAME_EDUCATION_TYPE
# NAME_FAMILY_STATUS
# MOBILE
# WORK_PHONE
# HOME_PHONE
# MOBILE_REACHABLE
# FLAG_EMAIL
# OCCUPATION_TYPE
# CNT_FAM_MEMBERS
# APPLICATION_DAY
# TOTAL_DOC_SUBMITTED

# %%
default=df[df["TARGET"]==1]
default
# Out:
#        SK_ID_CURR  TARGET NAME_CONTRACT_TYPE GENDER Car House  CNT_CHILDREN  \
# 0          100002       1         Cash loans      M   N     Y             0
# 26         100031       1         Cash loans      F   N     Y             0
# 40         100047       1         Cash loans      M   N     Y             0
# 42         100049       1         Cash loans      F   N     N             0
# 110        100130       1         Cash loans      F   N     Y             1
# ...           ...     ...                ...    ...  ..   ...           ...
# 99857      215926       1         Cash loans      M   Y     N             0
# 99920      216004       1         Cash loans      F   Y     Y             0
# 99932      216017       1         Cash loans      F   N     N             0
# 99935      216021       1         Cash loans      F   N     Y             0
# 99967      216057       1         Cash loans      M   N     N             0
#
# ...

# %%
Non_def=df[df["TARGET"]==0]
Non_def
# Out:
#        SK_ID_CURR  TARGET NAME_CONTRACT_TYPE GENDER Car House  CNT_CHILDREN  \
# 1          100003       0         Cash loans      F   N     N             0
# 2          100004       0    Revolving loans      M   Y     Y             0
# 3          100006       0         Cash loans      F   N     Y             0
# 4          100007       0         Cash loans      M   N     Y             0
# 5          100008       0         Cash loans      M   N     Y             0
# ...           ...     ...                ...    ...  ..   ...           ...
# 99995      216086       0         Cash loans      F   N     Y             1
# 99996      216087       0         Cash loans      F   N     Y             1
# 99997      216088       0         Cash loans      F   Y     Y             0
# 99998      216089       0         Cash loans      F   Y     N             0
# 99999      216090       0    Revolving loans      M   Y     Y             0
#
# ...

# %%
df['income'] = pd.cut(x=df['AMT_INCOME_TOTAL'], bins=[2000,200000,2000000,117000000])
sns.catplot(data=df,col = "NAME_CONTRACT_TYPE",x="income",hue="TARGET",kind="count",height=5,aspect=12/9)
plt.show()
# Out:
# <ipython-input-49-70e9683ce723>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['income'] = pd.cut(x=df['AMT_INCOME_TOTAL'], bins=[2000,200000,2000000,117000000])

# %%
df['credit'] = pd.cut(x=df['AMT_CREDIT'], bins=[40000,200000,1000000,4000000])
sns.catplot(data=df,col = "NAME_CONTRACT_TYPE",x="credit",hue="TARGET",kind="count",height=5,aspect=12/9)
plt.show()
# Out:
# <ipython-input-50-4b4c153d8bbb>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['credit'] = pd.cut(x=df['AMT_CREDIT'], bins=[40000,200000,1000000,4000000])

# %%
df['goods'] = pd.cut(x=df['AMT_GOODS_PRICE'], bins=[40000,100000,500000,1000000])
sns.catplot(data=df,col = "NAME_CONTRACT_TYPE",x="goods",hue="TARGET",kind="count",height=5,aspect=12/9)
plt.show()
# Out:
# <ipython-input-51-fad6b0d293d9>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['goods'] = pd.cut(x=df['AMT_GOODS_PRICE'], bins=[40000,100000,500000,1000000])

# %%
fig, ax = plt.subplots(1, figsize = (15, 7))
percentage = default["NAME_FAMILY_STATUS"].value_counts()     
labels = list(default["NAME_FAMILY_STATUS"].value_counts().index)
plt.pie(percentage,labels = ['Single / not married' ,'Married','Civil marriage','Separated','Widow'], autopct= "%0.2f%%",pctdistance = 0.7)  
plt.show()

# %%
fig, ax = plt.subplots(1, figsize = (15, 7))
percentage = Non_def["NAME_FAMILY_STATUS"].value_counts()     
labels = list(Non_def["NAME_FAMILY_STATUS"].value_counts().index)
plt.pie(percentage,labels = ['Single / not married' ,'Married','Civil marriage','Separated','Widow'], autopct= "%0.2f%%",pctdistance = 0.7)  
plt.show()

# %%
df.head()
# Out:
#    SK_ID_CURR  TARGET NAME_CONTRACT_TYPE GENDER Car House  CNT_CHILDREN  \
# 0      100002       1         Cash loans      M   N     Y             0
# 1      100003       0         Cash loans      F   N     N             0
# 2      100004       0    Revolving loans      M   Y     Y             0
# 3      100006       0         Cash loans      F   N     Y             0
# 4      100007       0         Cash loans      M   N     Y             0
#
#    AMT_INCOME_TOTAL  AMT_CREDIT  AMT_GOODS_PRICE  ... HOME_PHONE  \
# 0          202500.0    406597.5         351000.0  ...          0
# 1          270000.0   1293502.5        1129500.0  ...          0
# 2           67500.0    135000.0         135000.0  ...          1
# 3          135000.0    312682.5         297000.0  ...          0
# 4          121500.0    513000.0         513000.0  ...          0
#
#   MOBILE_REACHABLE FLAG_EMAIL OCCUPATION_TYPE  CNT_FAM_MEMBERS  \
# 0                1          0        Laborers              1.0
# ...

# %%
feature=['GENDER','Car','House','CNT_CHILDREN','CNT_FAM_MEMBERS','OCCUPATION_TYPE']

enumerate(feature)  
data=list(enumerate(feature)) 
data
plt.figure(figsize=(30,20))
for i in data: 
    print(i) 
    plt.subplot(3,2,i[0]+1)
    sns.countplot(x=i[1],hue="NAME_FAMILY_STATUS",data=default) 
    plt.title("Defaulter Analysis based on Occupation")
    plt.xticks(rotation=90)
# Out:
# (0, 'GENDER')
# (1, 'Car')
# (2, 'House')
# (3, 'CNT_CHILDREN')
# (4, 'CNT_FAM_MEMBERS')
# (5, 'OCCUPATION_TYPE')

# %%
feature=['GENDER','Car','House','CNT_CHILDREN','CNT_FAM_MEMBERS','OCCUPATION_TYPE']

enumerate(feature) 
data=list(enumerate(feature))
data
plt.figure(figsize=(30,20))
for i in data:
    print(i) 
    plt.subplot(3,2,i[0]+1)
    sns.countplot(x=i[1],hue="NAME_FAMILY_STATUS",data=Non_def) 
    plt.title("Non-Defaulter Analysis based on Occupation")
    plt.xticks(rotation=90)
# Out:
# (0, 'GENDER')
# (1, 'Car')
# (2, 'House')
# (3, 'CNT_CHILDREN')
# (4, 'CNT_FAM_MEMBERS')
# (5, 'OCCUPATION_TYPE')

# %%
df.head()
# Out:
#    SK_ID_CURR  TARGET NAME_CONTRACT_TYPE GENDER Car House  CNT_CHILDREN  \
# 0      100002       1         Cash loans      M   N     Y             0
# 1      100003       0         Cash loans      F   N     N             0
# 2      100004       0    Revolving loans      M   Y     Y             0
# 3      100006       0         Cash loans      F   N     Y             0
# 4      100007       0         Cash loans      M   N     Y             0
#
#    AMT_INCOME_TOTAL  AMT_CREDIT  AMT_GOODS_PRICE  ... HOME_PHONE  \
# 0          202500.0    406597.5         351000.0  ...          0
# 1          270000.0   1293502.5        1129500.0  ...          0
# 2           67500.0    135000.0         135000.0  ...          1
# 3          135000.0    312682.5         297000.0  ...          0
# 4          121500.0    513000.0         513000.0  ...          0
#
#   MOBILE_REACHABLE FLAG_EMAIL OCCUPATION_TYPE  CNT_FAM_MEMBERS  \
# 0                1          0        Laborers              1.0
# ...

# %%
fig, ax = plt.subplots(1, figsize = (15, 7))
percentage = Non_def["Car"].value_counts()     
labels = list(Non_def["Car"].value_counts().index)
plt.pie(percentage,labels = ['Yes','No'], autopct= "%0.2f%%")  
plt.show()

# %%
fig, ax = plt.subplots(1, figsize = (15, 7))
percentage = Non_def["House"].value_counts()     
labels = list(Non_def["House"].value_counts().index)
plt.pie(percentage,labels = ['Yes','No'], autopct= "%0.2f%%")  
plt.show()

# %%
#df_5=df[(df.TARGET == 0)]
Non_def['income'] = pd.cut(x=Non_def['AMT_INCOME_TOTAL'], bins=[2000,200000,2000000,117000000])
#sns.countplot(x='income',hue='OCCUPATION_TYPE',data=Non_def)
sns.catplot(data=Non_def,col = "TOTAL_DOC_SUBMITTED",x="income",hue = 'OCCUPATION_TYPE',kind="count",height=7)
plt.show()
# Out:
# <ipython-input-65-43552e4a746b>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Non_def['income'] = pd.cut(x=Non_def['AMT_INCOME_TOTAL'], bins=[2000,200000,2000000,117000000])

# %%
fig, ax = plt.subplots(1, figsize = (15, 7))
percentage = default["Car"].value_counts()     
labels = list(default["Car"].value_counts().index)
plt.pie(percentage,labels = ['Yes','No'], autopct= "%0.2f%%")  
plt.show()

# %%
fig, ax = plt.subplots(1, figsize = (15, 7))
percentage = default["House"].value_counts()     
labels = list(default["House"].value_counts().index)
plt.pie(percentage,labels = ['Yes','No'], autopct= "%0.2f%%")  
plt.show()

# %%
default['income'] = pd.cut(x=default['AMT_INCOME_TOTAL'], bins=[2000,200000,2000000,117000000])
sns.catplot(data=default,col = "TOTAL_DOC_SUBMITTED",x="income",hue = 'OCCUPATION_TYPE',kind="count",height=7)
plt.show()
# Out:
# <ipython-input-68-2a36dc7de5c0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   default['income'] = pd.cut(x=default['AMT_INCOME_TOTAL'], bins=[2000,200000,2000000,117000000])

# %%
df.head()
# Out:
#    SK_ID_CURR  TARGET NAME_CONTRACT_TYPE GENDER Car House  CNT_CHILDREN  \
# 0      100002       1         Cash loans      M   N     Y             0
# 1      100003       0         Cash loans      F   N     N             0
# 2      100004       0    Revolving loans      M   Y     Y             0
# 3      100006       0         Cash loans      F   N     Y             0
# 4      100007       0         Cash loans      M   N     Y             0
#
#    AMT_INCOME_TOTAL  AMT_CREDIT  AMT_GOODS_PRICE  ... HOME_PHONE  \
# 0          202500.0    406597.5         351000.0  ...          0
# 1          270000.0   1293502.5        1129500.0  ...          0
# 2           67500.0    135000.0         135000.0  ...          1
# 3          135000.0    312682.5         297000.0  ...          0
# 4          121500.0    513000.0         513000.0  ...          0
#
#   MOBILE_REACHABLE FLAG_EMAIL OCCUPATION_TYPE  CNT_FAM_MEMBERS  \
# 0                1          0        Laborers              1.0
# ...

# %%
new=df[(df.TARGET == 1) & (df.NAME_CONTRACT_TYPE =='Cash loans') & (df.Car == 'Y') & (df.House == 'Y')
       & (df.CNT_CHILDREN <= 3)& (df.CNT_FAM_MEMBERS <= 2) &(df.AMT_INCOME_TOTAL >=2000.0)&(df.AMT_GOODS_PRICE >=10000)
       &(df.TOTAL_DOC_SUBMITTED >0)]
print(new.count())
print(len(new))
# Out:
# SK_ID_CURR             797
# TARGET                 797
# NAME_CONTRACT_TYPE     797
# GENDER                 797
# Car                    797
# House                  797
# CNT_CHILDREN           797
# AMT_INCOME_TOTAL       797
# AMT_CREDIT             797
# AMT_GOODS_PRICE        797
# NAME_TYPE_SUITE        797
# NAME_INCOME_TYPE       797
# NAME_EDUCATION_TYPE    797
# NAME_FAMILY_STATUS     797
# DAYS_EMPLOYED          797
# MOBILE                 797
# WORK_PHONE             797
# HOME_PHONE             797
# MOBILE_REACHABLE       797
# FLAG_EMAIL             797
# OCCUPATION_TYPE        797
# CNT_FAM_MEMBERS        797
# APPLICATION_DAY        797
# TOTAL_DOC_SUBMITTED    797
# income                 797
# credit                 797
# goods                  736
# dtype: int64
# 797

# %%
df
# Out:
#        SK_ID_CURR  TARGET NAME_CONTRACT_TYPE GENDER Car House  CNT_CHILDREN  \
# 0          100002       1         Cash loans      M   N     Y             0
# 1          100003       0         Cash loans      F   N     N             0
# 2          100004       0    Revolving loans      M   Y     Y             0
# 3          100006       0         Cash loans      F   N     Y             0
# 4          100007       0         Cash loans      M   N     Y             0
# ...           ...     ...                ...    ...  ..   ...           ...
# 99995      216086       0         Cash loans      F   N     Y             1
# 99996      216087       0         Cash loans      F   N     Y             1
# 99997      216088       0         Cash loans      F   Y     Y             0
# 99998      216089       0         Cash loans      F   Y     N             0
# 99999      216090       0    Revolving loans      M   Y     Y             0
#
# ...

# %%
non_defaulters=df[(df.TARGET == 0) & (df.Car == 'Y') & (df.House == 'Y') & (df.CNT_CHILDREN <= 3) & (df.CNT_FAM_MEMBERS <= 5) &(df.AMT_INCOME_TOTAL >=2000) &(df.AMT_GOODS_PRICE >=10000) & (df.TOTAL_DOC_SUBMITTED >0) ]
non_defaulters
# Out:
#        SK_ID_CURR  TARGET NAME_CONTRACT_TYPE GENDER Car House  CNT_CHILDREN  \
# 6          100009       0         Cash loans      F   Y     Y             1
# 7          100010       0         Cash loans      M   Y     Y             0
# 15         100019       0         Cash loans      M   Y     Y             0
# 21         100025       0         Cash loans      F   Y     Y             1
# 49         100056       0         Cash loans      M   Y     Y             0
# ...           ...     ...                ...    ...  ..   ...           ...
# 99970      216060       0         Cash loans      F   Y     Y             1
# 99975      216066       0         Cash loans      M   Y     Y             0
# 99984      216075       0         Cash loans      F   Y     Y             0
# 99985      216076       0         Cash loans      M   Y     Y             0
# 99997      216088       0         Cash loans      F   Y     Y             0
#
# ...

# %%
non_defaulters.to_excel("eligible for loan.xlsx")

# %%
fig, ax = plt.subplots(1, figsize = (15, 7))
percentage = Non_def["NAME_EDUCATION_TYPE"].value_counts()     
labels = list(Non_def["NAME_EDUCATION_TYPE"].value_counts().index)
plt.pie(percentage,labels = ['Secondary / secondary special','Higher education','Incomplete higher',
 'Lower secondary','Academic degree'], autopct= "%0.1f%%",pctdistance = 0.5)  
plt.show()
